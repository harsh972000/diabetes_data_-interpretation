# %% [markdown]
# ## key findings
# 1. 16 % of patients are repeating
# 2. caucasian rece patients are highest in number followed by african american
# 3. females of age (70-90) and male age (60-80) are more likly to prone with diabetes
# 4. more females are prone with diabetes
# 5. 90 % of diebetes patients are in between 50-90 year of age
# 6. more females took emergency treatment than males
# 7. people with age between 50-80 takes emergency treatments
# 8. males with age 70-80 and female with age 80-90 are more liky to admiited in hospital
# 9. table drawn for each medine reveals that
# 10. metaformin, glimpiridine , glipizide, glyburide, pioglitazone , rosiglitazone are most used medicine for age between 50-90
# 11. repagliodine, neteglindine, chlorpromide , tolbutamide, acarbose, migliton, glybunde.met0formine used intermediatry
# 12. acetonexamide,  troglitazone, tolazamide, examide, citoglipton, glipizide.metaformine,  metformin.pioglitazone metformin.rosiglitazone very less used or no used.
# 13. most steady level of insuline given to age between 70-90
# 14. people with high medication have little pecularity
# 15.  they age between 60-80
# 16. most are male ( generally female was higher in number )
# 17.  they need upped level of insuline
# 18. class object describe the whole data at once

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as ex
import warnings
warnings.filterwarnings('ignore', module="matplotlib..\*")

# %%
pd.set_option('display.max_columns', 100)
data = pd.read_csv(r'D:\Users\91917\Downloads\diabetes.csv')

# %%
# perscentage of patients number which is reapeating 

bad = data.patient_nbr.value_counts()
bad[bad>1].shape[0]/ data.shape[0] * 100
# Out:
# 16.481929131537058

# %%
# caucasian has highest in number followed by african American
plt.figure(figsize = (10,7))
sns.countplot(data.race)
# Out:
# C:\Users\91917\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='race', ylabel='count'>

# %%
# females of age (70-90) and male age (60-80) are more likly to prone with diebetes 

pd.crosstab(data.gender, data.age).plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
# female is higher in number in tern of grabbing diebetes 
sns.countplot(data.gender)
# Out:
# C:\Users\91917\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
## 90 % of diebetes patients are in between 50-90 year of age
sns.countplot(data.age)
# Out:
# C:\Users\91917\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
# females need more emergency treatment than male 
data.groupby('gender')['number_emergency'].count().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
# mostly age 50-90 need emergency 
data.groupby('age')['number_emergency'].count().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
# females stayed less than male in hospital 

data.groupby('gender')['number_outpatient'].count().plot(kind ='bar')
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
# also the numbers of females are much greater who admitted in hospital more more than 1 day
data.groupby('gender')['number_inpatient'].count().plot(kind ='bar')
# Out:
# <AxesSubplot:xlabel='gender'>

# %%
# males with age 70-80 and  female with age 80-90 are more liky to admiited in hospital 
pd.crosstab(index=data['age'], columns=data['gender'], values= data['number_inpatient'], aggfunc=np.sum).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
pd.crosstab(index=data['age'], columns=data['gender'], values= data['number_outpatient'], aggfunc=np.sum).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='age'>

# %%
# table showing the use of nateglinidin, age between 60-90 use it steady and for age 70-90 this doses could increased

pd.crosstab(index=data.age, columns=data['nateglinide'])#.plot(kind= 'bar', table = True, figsize = (30, 7))
# Out:
# nateglinide  Down     No  Steady  Up
# age
# [0-10)          0    161       0   0
# [10-20)         0    690       1   0
# [20-30)         0   1656       1   0
# [30-40)         0   3758      17   0
# [40-50)         1   9629      53   2
# [50-60)         2  17155      93   6
# [60-70)         2  22327     153   1
# [70-80)         3  25866     191   8
# [80-90)         2  17062     127   6
# [90-100)        1   2759      32   1

# %%
# tables containing information of all medicine used for diffent age groups.
mediation = data.iloc[:,25:]
def medication(medi, m,n, columns = 2 ):
    for e,i in enumerate(medi.columns):
        print(pd.crosstab(index=data.age, columns=data[i]),end = '\n')
        print()

# %%
medication(mediation, 10,5)
# Out:
# metformin  Down     No  Steady   Up
# age
# [0-10)        0    161       0    0
# [10-20)       1    645      40    5
# [20-30)       3   1486     152   16
# [30-40)      19   3016     684   56
# [40-50)      63   7371    2101  150
# [50-60)     116  13085    3811  244
# [60-70)     166  17436    4649  232
# [70-80)     134  21115    4576  243
# [80-90)      64  14893    2129  111
# [90-100)      9   2570     204   10
#
# repaglinide  Down     No  Steady  Up
# age
# [0-10)          0    161       0   0
# [10-20)         0    690       0   1
# [20-30)         0   1653       3   1
# [30-40)         0   3763      11   1
# [40-50)         1   9621      57   6
# [50-60)         3  17065     177  11
# [60-70)        13  22146     303  21
# [70-80)        11  25648     382  27
# [80-90)        15  16763     385  34
# [90-100)        2   2717      66   8
#
# nateglinide  Down     No  Steady  Up
# age
# [0-10)          0    161       0   0
# [10-20)         0    690       1   0
# ...

# %%
def medicatin(medi, m,n, columns = 2 ):
    shap = medi.shape[1]

    import warnings
    warnings.filterwarnings('ignore')
    row = (shap/columns)
    rows = np.ceil(row)
    plt.figure(figsize = (m,n))
    for e,i in enumerate(medi.columns):
        plt.subplot(rows, columns , e+1)
        sns.countplot(x = data.age, hue = medi[i])

# %%
### use of different types of medicine and its effect of differnt age groups 
medicatin(mediation, 20, 70)

# %%
# gender wise uses of medicine and its results 
def medicatin(medi, m,n, columns = 2 ):
    shap = medi.shape[1]
    row = (shap/columns)
    rows = np.ceil(row)
    warnings.filterwarnings('ignore')
    plt.figure(figsize = (m,n))
    for e,i in enumerate(medi.columns):
        plt.subplot(rows, columns , e+1)
        sns.countplot(x = data.gender, hue = medi[i])

# %%
medicatin(mediation, 20, 70)

# %%
# distribution of weights on gender most of males are weight between 75-100 and females are between 50-100
df['weight'] = df.weight.replace('?', np.nan)
df = df.dropna()
pd.crosstab(df.weight, df.gender).plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='weight'>

# %%
# central tendency of int object 
def intjo(medi, m, n, columns = 2):
    fil = medi.select_dtypes('int').columns
    es = len(fil)
    row = (es/columns)
    rows = int(np.ceil(row))
    plt.figure(figsize = (m,n))
  
    for e,i in enumerate(fil):
        plt.subplot(rows,columns, e+1)
        sns.histplot(x= medi[i])

# %%
intjo(data, 20, 30)

# %%
# since the no_of medication has high skewness in data, mean people have using more then 60 medication, so we decided to 
# describe the people who taking more medicaiton 

dog = data.num_medications.sort_values(ascending=False)
boak = dog.index[dog >= 40]
high_med = data.iloc[boak]

# %%
# people age between 60 to 80 taking high medicaiton 
sns.countplot(high_med.age)
# Out:
# C:\Users\91917\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
# most of people have upped and steady insulin level as expected
sns.countplot(high_med.insulin)
# Out:
# C:\Users\91917\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='insulin', ylabel='count'>

# %%
# here is class which describe all the above code in just three line after impletation it is describing the whole data


class meraplot:
    import seaborn as sns
    import matplotlib.pyplot as plt
    import pandas as pd
    from ipywidgets import interactive, interact
    
    
    def __init__(self, data):
        self.data = data
        self.columns = data.columns
        
        
        
        
    def make_hist(self, wid, leng, columns = 2):
        fil = self.data.select_dtypes('int' or 'float').columns
        print(fil)
        es = len(fil)
        row = (es/columns)
        rows = int(np.ceil(row))
        plt.figure(figsize = (wid, leng))
        for e,i in enumerate(fil):
            plt.subplot(rows,columns, e+1)
            sns.histplot(x= self.data[i])
       
    def make_object(self, wid, leng, columns = 2):
        fil = self.data.select_dtypes('object').columns
        print(fil)
        es = len(fil)
        row = (es/columns)
        rows = int(np.ceil(row))
        plt.figure(figsize = (wid, leng))
        for e,i in enumerate(fil):
            plt.subplot(rows,columns, e+1)
            sns.countplot(x= self.data[i])
            plt.xticks(rotation = 45)
            
            
    def relation_table(self, index, col):
        print(pd.crosstab(self.data[index], self.data[col]))
        
    def relation_bar(self, index, col):
        pd.crosstab(self.data[index], self.data[col]).plot(kind = 'bar')

# %%
de = meraplot(high_med)

# %%
de.make_object(30,200)
# Out:
# Index(['race', 'gender', 'age', 'weight', 'payer_code', 'medical_specialty',
#        'diag_1', 'diag_2', 'diag_3', 'max_glu_serum', 'A1Cresult', 'metformin',
#        'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride',
#        'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide.metformin', 'glipizide.metformin',
#        'glimepiride.pioglitazone', 'metformin.rosiglitazone',
#        'metformin.pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')
